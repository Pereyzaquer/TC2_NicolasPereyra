# %% [markdown]
# # Primer Parcial
# ## Nicolas Pereyra

# %% [markdown]
# ### Preguntas:

# %%
# Incorporacion y visualizacion de PDF
from IPython.display import IFrame
IFrame("1er Parcial - R4001 - 20230713.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="1er Parcial - R4001 - 20230713.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Ejercicio 1:

# %% [markdown]
# ![WhatsApp%20Image%202023-07-13%20at%2012.02.43.jpeg](attachment:WhatsApp%20Image%202023-07-13%20at%2012.02.43.jpeg)

# %% [markdown]
# ![WhatsApp%20Image%202023-07-13%20at%2012.02.44.jpeg](attachment:WhatsApp%20Image%202023-07-13%20at%2012.02.44.jpeg)

# %% [markdown]
# ![WhatsApp%20Image%202023-07-13%20at%2012.05.17.jpeg](attachment:WhatsApp%20Image%202023-07-13%20at%2012.05.17.jpeg)

# %%
from scipy import signal
import matplotlib.pyplot as plt
import numpy as np
from pytc2.sistemas_lineales import analyze_sys, pretty_print_bicuad_omegayq, tf2sos_analog, pretty_print_SOS
from pytc2.general import print_subtitle

atemin = 1 # dB
n = 2 # Orden
wo = 1 # fc
bw = 0.1
q = 1/bw

## Pasa bajos normalizado
[z_lp, p_lp, k_lp] = signal.cheb1ap(n, atemin)
[b_lp, a_lp] = signal.zpk2tf(z_lp, p_lp, k_lp)

filter_lp = tf2sos_analog(b_lp, a_lp)
print_subtitle('Transferencia de filtro pasa Bajos (Normalizado)')
pretty_print_SOS(filter_lp, mode='omegayq')

tf_lp = signal.TransferFunction(b_lp, a_lp)
analyze_sys(tf_lp)
# Out:
# #### Transferencia de filtro pasa Bajos (Normalizado)
# $\displaystyle   \frac{0.9826 }{s^2 + s \frac{1.05}{0.9565} + 1.05^2}$

# %%
## La siguiente funcion tiraba error por un problema que se desconoce
## Pasa altos normalizado

[b_bp, a_bp]=signal.lp2bp(b_lp, a_lp, wo, bw)
tf_bp = signal.TransferFunction(b_bp, a_bp)

analyze_sys(tf_bp)
#print(tf_bp)

# %%
filter_bp = tf2sos_analog(b_bp, a_bp)
print_subtitle('Transferencia de filtro pasa Banda (Normalizado)')
pretty_print_SOS(filter_bp, mode='omegayq')
# Out:
# #### Transferencia de filtro pasa Banda (Normalizado)
# $\displaystyle   \frac{s\,0.939\,\frac{0.9562}{18.24}}{s^2 + s \frac{0.9562}{18.24} + 0.9562^2} . \frac{s\,3.481\,\frac{1.046}{18.24}}{s^2 + s \frac{1.046}{18.24} + 1.046^2}$

# %% [markdown]
# ![1_pasivo.png](attachment:1_pasivo.png)

# %% [markdown]
# ## Ejercicio 2:
# ![WhatsApp%20Image%202023-07-13%20at%2012.05.16%281%29.jpeg](attachment:WhatsApp%20Image%202023-07-13%20at%2012.05.16%281%29.jpeg)

# %% [markdown]
# ![WhatsApp%20Image%202023-07-13%20at%2012.05.16.jpeg](attachment:WhatsApp%20Image%202023-07-13%20at%2012.05.16.jpeg)

# %% [markdown]
# ## Ejercicio 3:
# ![WhatsApp%20Image%202023-07-13%20at%2012.02.45.jpeg](attachment:WhatsApp%20Image%202023-07-13%20at%2012.02.45.jpeg)![WhatsApp%20Image%202023-07-13%20at%2012.02.48.jpeg](attachment:WhatsApp%20Image%202023-07-13%20at%2012.02.48.jpeg)

# %% [markdown]
# ![WhatsApp%20Image%202023-07-13%20at%2012.02.49.jpeg](attachment:WhatsApp%20Image%202023-07-13%20at%2012.02.49.jpeg)

# %% [markdown]
# ![WhatsApp%20Image%202023-07-13%20at%2012.02.49%281%29.jpeg](attachment:WhatsApp%20Image%202023-07-13%20at%2012.02.49%281%29.jpeg)

# %% [markdown]
# ![WhatsApp%20Image%202023-07-13%20at%2012.02.49%282%29.jpeg](attachment:WhatsApp%20Image%202023-07-13%20at%2012.02.49%282%29.jpeg)

# %% [markdown]
# ![punto3.png](attachment:punto3.png)
